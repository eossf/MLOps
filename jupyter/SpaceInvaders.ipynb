# %% [markdown]
# ## Dependencies

# %%
# !pip install tensorflow==2.6.0rc1 
# !pip install gym 
# !pip install keras-rl2 
# !pip install gym[atari] 
# !pip install pyopengl
# Out:
# Collecting tensorflow==2.6.0rc1
#   Downloading tensorflow-2.6.0rc1-cp39-cp39-manylinux2010_x86_64.whl (458.3 MB)
#      |████████████████████████████████| 458.3 MB 354 bytes/s  0:00:015
# Requirement already satisfied: google-pasta~=0.2 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (0.2.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (1.12)
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
# Requirement already satisfied: typing-extensions~=3.7.4 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (3.7.4.3)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (1.37.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (1.1.2)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (3.15.8)
# Requirement already satisfied: wheel~=0.35 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (0.37.0)
# Requirement already satisfied: astunparse~=1.6.3 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (1.6.3)
# Collecting tensorflow-estimator<2.7.0,>=2.6.0rc0
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 1.8 MB/s eta 0:00:01
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp39-cp39-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: opt-einsum~=3.3.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (3.3.0)
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp39-cp39-manylinux2010_x86_64.whl (14.9 MB)
#      |████████████████████████████████| 14.9 MB 2.3 MB/s eta 0:00:01
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: termcolor~=1.1.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (1.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (1.12.1)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (1.15.0)
# Collecting keras<2.7.0,>=2.6.0rc1
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: absl-py~=0.10 in /opt/conda/lib/python3.9/site-packages (from tensorflow==2.6.0rc1) (0.13.0)
# Collecting tensorboard~=2.5
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 3.6 kB/s eta 0:00:01
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow==2.6.0rc1) (2.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow==2.6.0rc1) (58.0.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow==2.6.0rc1) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow==2.6.0rc1) (2.26.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow==2.6.0rc1) (3.3.4)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 90 kB/s  eta 0:00:01
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow==2.6.0rc1) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow==2.6.0rc1) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.6.0rc1) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.6.0rc1) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.6.0rc1) (0.2.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.6.0rc1) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.6.0rc1) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.6.0rc1) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.6.0rc1) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.6.0rc1) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.6.0rc1) (3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.6.0rc1) (3.1.1)
# Building wheels for collected packages: clang
#   Building wheel for clang (setup.py) ... done
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30692 sha256=f39ad09a5a35ec5692f28caa39c933ebc361f9741edab60c515b992c184342f6
#   Stored in directory: /home/jovyan/.cache/pip/wheels/3a/ce/7a/27094f689461801c934296d07078773603663dfcaca63bb064
# Successfully built clang
# Installing collected packages: tensorboard-data-server, numpy, tensorflow-estimator, tensorboard, keras, h5py, gast, clang, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.4.3
#     Uninstalling tensorflow-2.4.3:
#       Successfully uninstalled tensorflow-2.4.3
# Successfully installed clang-5.0 gast-0.4.0 h5py-3.1.0 keras-2.6.0 numpy-1.19.5 tensorboard-2.6.0 tensorboard-data-server-0.6.1 tensorflow-2.6.0rc1 tensorflow-estimator-2.6.0
# Collecting gym
#   Downloading gym-0.20.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.18.0 in /opt/conda/lib/python3.9/site-packages (from gym) (1.19.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from gym) (2.0.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.20.0-py3-none-any.whl size=1650479 sha256=a65b5486bc887c194480e2c516349e37e6c72607e029e9aa98eec0b80ab89a1c
#   Stored in directory: /home/jovyan/.cache/pip/wheels/9f/91/e5/ac160083c57e371f1137b11482894fca821597dc5961fb9e8c
# Successfully built gym
# Installing collected packages: gym
# Successfully installed gym-0.20.0
# Collecting keras-rl2
#   Downloading keras_rl2-1.0.5-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 5.2 kB/s eta 0:00:01
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.9/site-packages (from keras-rl2) (2.6.0rc1)
# Requirement already satisfied: absl-py~=0.10 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (0.13.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.12.1)
# Requirement already satisfied: google-pasta~=0.2 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: tensorboard~=2.5 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (2.6.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: gast==0.4.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (0.4.0)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (3.15.8)
# Requirement already satisfied: typing-extensions~=3.7.4 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (3.7.4.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.12)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.37.1)
# Requirement already satisfied: keras<2.7.0,>=2.6.0rc1 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (2.6.0)
# Requirement already satisfied: wheel~=0.35 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (0.37.0)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.15.0)
# Requirement already satisfied: clang~=5.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (5.0)
# Requirement already satisfied: numpy~=1.19.2 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.19.5)
# Requirement already satisfied: astunparse~=1.6.3 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (3.1.0)
# Requirement already satisfied: tensorflow-estimator<2.7.0,>=2.6.0rc0 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (2.6.0)
# Requirement already satisfied: termcolor~=1.1.0 in /opt/conda/lib/python3.9/site-packages (from tensorflow->keras-rl2) (1.1.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow->keras-rl2) (2.26.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow->keras-rl2) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow->keras-rl2) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow->keras-rl2) (2.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow->keras-rl2) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow->keras-rl2) (58.0.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow->keras-rl2) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/lib/python3.9/site-packages (from tensorboard~=2.5->tensorflow->keras-rl2) (1.8.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->keras-rl2) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->keras-rl2) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.9/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->keras-rl2) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->keras-rl2) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->keras-rl2) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->keras-rl2) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->keras-rl2) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->keras-rl2) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->keras-rl2) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->keras-rl2) (3.1.1)
# Installing collected packages: keras-rl2
# Successfully installed keras-rl2-1.0.5
# Requirement already satisfied: gym[atari] in /opt/conda/lib/python3.9/site-packages (0.20.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.9/site-packages (from gym[atari]) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /opt/conda/lib/python3.9/site-packages (from gym[atari]) (1.19.5)
# Collecting ale-py~=0.7
#   Downloading ale_py-0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 86 kB/s  eta 0:00:01
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.9/site-packages (from ale-py~=0.7->gym[atari]) (5.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.9/site-packages (from importlib-resources->ale-py~=0.7->gym[atari]) (3.5.0)
# Installing collected packages: ale-py
# Successfully installed ale-py-0.7
# Collecting pyopengl
#   Downloading PyOpenGL-3.1.5-py3-none-any.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 78 kB/s  eta 0:00:01
# Installing collected packages: pyopengl
# Successfully installed pyopengl-3.1.5

# %%
# !pip install atari_py
# !python3 -m atari_py.import_roms ROMS
# Out:
# Requirement already satisfied: atari_py in /opt/conda/lib/python3.9/site-packages (0.2.9)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from atari_py) (1.15.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from atari_py) (1.19.5)
# copying air_raid.bin from ROMS/Air Raid (Men-A-Vision) (PAL) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/air_raid.bin
# copying video_pinball.bin from ROMS/Video Pinball - Arcade Pinball (1981) (Atari, Bob Smith - Sears) (CX2648 - 49-75161) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/video_pinball.bin
# copying surround.bin from ROMS/Surround - Chase (Blockade) (1977) (Atari, Alan Miller - Sears) (CX2641 - 99807, 49-75105) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/surround.bin
# copying venture.bin from ROMS/Venture (1982) (Coleco, Joseph Biel) (2457) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/venture.bin
# copying donkey_kong.bin from ROMS/Donkey Kong (1987) (Atari) (CX26143).bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/donkey_kong.bin
# copying road_runner.bin from patched version of ROMS/Road Runner (1989) (Atari - Bobco, Robert C. Polaro) (CX2663) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/road_runner.bin
# copying freeway.bin from ROMS/Freeway (1981) (Activision, David Crane) (AG-009, AG-009-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/freeway.bin
# copying gravitar.bin from ROMS/Gravitar (1983) (Atari, Dan Hitchens, Mimi Nyden) (CX2685) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/gravitar.bin
# copying demon_attack.bin from ROMS/Demon Attack (Death from Above) (1982) (Imagic, Rob Fulop) (720000-200, 720101-1B, 720101-1C, IA3200, IA3200C, IX-006-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/demon_attack.bin
# copying beam_rider.bin from ROMS/Beamrider (1984) (Activision - Cheshire Engineering, David Rolfe, Larry Zwick) (AZ-037-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/beam_rider.bin
# copying gopher.bin from ROMS/Gopher (Gopher Attack) (1982) (U.S. Games Corporation - JWDA, Sylvia Day, Todd Marshall, Robin McDaniel, Henry Will IV) (VC2001) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/gopher.bin
# copying pooyan.bin from ROMS/Pooyan (1983) (Konami) (RC 100-X 02) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/pooyan.bin
# copying skiing.bin from ROMS/Skiing - Le Ski (1980) (Activision, Bob Whitehead) (AG-005, CAG-005, AG-005-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/skiing.bin
# copying chopper_command.bin from ROMS/Chopper Command (1982) (Activision, Bob Whitehead) (AX-015, AX-015-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/chopper_command.bin
# copying lost_luggage.bin from ROMS/Lost Luggage (Airport Mayhem) (1982) (Apollo - Games by Apollo, Larry Minor, Ernie Runyon, Ed Salvo) (AP-2004) [no opening scene] ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/lost_luggage.bin
# copying fishing_derby.bin from ROMS/Fishing Derby (1980) (Activision, David Crane) (AG-004) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/fishing_derby.bin
# copying galaxian.bin from ROMS/Galaxian (1983) (Atari - GCC, Mark Ackerman, Tom Calderwood, Glenn Parker) (CX2684) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/galaxian.bin
# copying kaboom.bin from ROMS/Kaboom! (Paddle) (1981) (Activision, Larry Kaplan, David Crane) (AG-010, AG-010-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/kaboom.bin
# copying kung_fu_master.bin from ROMS/Kung-Fu Master (1987) (Activision - Imagineering, Dan Kitchen, Garry Kitchen) (AG-039-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/kung_fu_master.bin
# copying mr_do.bin from ROMS/Mr. Do! (1983) (CBS Electronics, Ed English) (4L4478) (PAL).bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/mr_do.bin
# copying keystone_kapers.bin from ROMS/Keystone Kapers - Raueber und Gendarm (1983) (Activision, Garry Kitchen - Ariola) (EAX-025, EAX-025-04I - 711 025-725) (PAL).bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/keystone_kapers.bin
# copying montezuma_revenge.bin from ROMS/Montezuma's Revenge - Featuring Panama Joe (1984) (Parker Brothers - JWDA, Henry Will IV) (PB5760) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/montezuma_revenge.bin
# copying hero.bin from ROMS/H.E.R.O. (1984) (Activision, John Van Ryzin) (AZ-036-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/hero.bin
# copying kangaroo.bin from ROMS/Kangaroo (1983) (Atari - GCC, Kevin Osborn) (CX2689) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/kangaroo.bin
# copying private_eye.bin from ROMS/Private Eye (1984) (Activision, Bob Whitehead) (AG-034-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/private_eye.bin
# copying adventure.bin from ROMS/Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/adventure.bin
# copying assault.bin from ROMS/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/assault.bin
# copying bowling.bin from ROMS/Bowling (1979) (Atari, Larry Kaplan - Sears) (CX2628 - 6-99842, 49-75117) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/bowling.bin
# copying zaxxon.bin from ROMS/Zaxxon (1983) (Coleco) (2454) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/zaxxon.bin
# copying phoenix.bin from ROMS/Phoenix (1983) (Atari - GCC, Mike Feinstein, John Mracek) (CX2673) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/phoenix.bin
# copying ms_pacman.bin from ROMS/Ms. Pac-Man (1983) (Atari - GCC, Mark Ackerman, Glenn Parker) (CX2675) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/ms_pacman.bin
# copying robotank.bin from ROMS/Robot Tank (Robotank) (1983) (Activision, Alan Miller) (AZ-028, AG-028-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/robotank.bin
# copying berzerk.bin from ROMS/Berzerk (1982) (Atari, Dan Hitchens - Sears) (CX2650 - 49-75168) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/berzerk.bin
# copying qbert.bin from ROMS/Q-bert (1983) (Parker Brothers - Western Technologies, Dave Hampton, Tom Sloper) (PB5360) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/qbert.bin
# copying koolaid.bin from ROMS/Kool-Aid Man (Kool Aid Pitcher Man) (1983) (M Network, Stephen Tatsumi, Jane Terjung - Kool Aid) (MT4648) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/koolaid.bin
# copying defender.bin from ROMS/Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/defender.bin
# copying atlantis.bin from ROMS/Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-1A, 720103-1B, IA3203, IX-010-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/atlantis.bin
# copying tutankham.bin from ROMS/Tutankham (1983) (Parker Brothers, Dave Engman, Dawn Stockbridge) (PB5340) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/tutankham.bin
# copying space_invaders.bin from ROMS/Space Invaders (1980) (Atari, Richard Maurer - Sears) (CX2632 - 49-75153) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/space_invaders.bin
# copying sir_lancelot.bin from ROMS/Sir Lancelot (1983) (Xonox - K-Tel Software - Product Guild, Anthony R. Henderson) (99006, 6220) (PAL).bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/sir_lancelot.bin
# copying frostbite.bin from ROMS/Frostbite (1983) (Activision, Steve Cartwright) (AX-031) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/frostbite.bin
# copying elevator_action.bin from ROMS/Elevator Action (1983) (Atari, Dan Hitchens) (CX26126) (Prototype) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/elevator_action.bin
# copying journey_escape.bin from ROMS/Journey Escape (1983) (Data Age, J. Ray Dettling) (112-006) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/journey_escape.bin
# copying breakout.bin from ROMS/Breakout - Breakaway IV (Paddle) (1978) (Atari, Brad Stewart - Sears) (CX2622 - 6-99813, 49-75107) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/breakout.bin
# copying asterix.bin from ROMS/Asterix (AKA Taz) (1984) (Atari, Jerome Domurat, Steve Woita) (CX2696).bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/asterix.bin
# copying tennis.bin from ROMS/Tennis - Le Tennis (1981) (Activision, Alan Miller) (AG-007, CAG-007) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/tennis.bin
# copying riverraid.bin from ROMS/River Raid (1982) (Activision, Carol Shaw) (AX-020, AX-020-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/riverraid.bin
# copying enduro.bin from ROMS/Enduro (1983) (Activision, Larry Miller) (AX-026, AX-026-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/enduro.bin
# copying yars_revenge.bin from ROMS/Yars' Revenge (Time Freeze) (1982) (Atari, Howard Scott Warshaw - Sears) (CX2655 - 49-75167) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/yars_revenge.bin
# copying crazy_climber.bin from ROMS/Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/crazy_climber.bin
# copying laser_gates.bin from ROMS/Laser Gates (AKA Innerspace) (1983) (Imagic, Dan Oliver) (720118-2A, 13208, EIX-007-04I) (PAL).bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/laser_gates.bin
# copying boxing.bin from ROMS/Boxing - La Boxe (1980) (Activision, Bob Whitehead) (AG-002, CAG-002, AG-002-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/boxing.bin
# copying jamesbond.bin from ROMS/James Bond 007 (James Bond Agent 007) (1984) (Parker Brothers - On-Time Software, Joe Gaucher, Louis Marbel) (PB5110) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/jamesbond.bin
# copying pacman.bin from ROMS/Pac-Man (1982) (Atari, Tod Frye) (CX2646) (PAL).bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/pacman.bin
# copying king_kong.bin from ROMS/King Kong (1982) (Tigervision - Software Electronics Corporation, Karl T. Olinger - Teldec) (7-001 - 3.60001 VE) (PAL).bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/king_kong.bin
# copying asteroids.bin from ROMS/Asteroids (1981) (Atari, Brad Stewart - Sears) (CX2649 - 49-75163) [no copyright] ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/asteroids.bin
# copying krull.bin from ROMS/Krull (1983) (Atari, Jerome Domurat, Dave Staugas) (CX2682) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/krull.bin
# copying trondead.bin from ROMS/TRON - Deadly Discs (TRON Joystick) (1983) (M Network - INTV - APh Technological Consulting, Jeff Ronne, Brett Stutz) (MT5662) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/trondead.bin
# copying ice_hockey.bin from ROMS/Ice Hockey - Le Hockey Sur Glace (1981) (Activision, Alan Miller) (AX-012, CAX-012, AX-012-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/ice_hockey.bin
# copying alien.bin from ROMS/Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/alien.bin
# copying wizard_of_wor.bin from ROMS/Wizard of Wor (1982) (CBS Electronics - Roklan, Joe Hellesen, Joe Wagner) (M8774, M8794) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/wizard_of_wor.bin
# copying up_n_down.bin from ROMS/Up 'n Down (1984) (SEGA - Beck-Tech, Steve Beck, Phat Ho) (009-01) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/up_n_down.bin
# copying star_gunner.bin from ROMS/Stargunner (1983) (Telesys, Alex Leavens) (1005) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/star_gunner.bin
# copying frogger.bin from ROMS/Frogger (1982) (Parker Brothers, Ed English, David Lamkins) (PB5300) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/frogger.bin
# copying seaquest.bin from ROMS/Seaquest (1983) (Activision, Steve Cartwright) (AX-022) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/seaquest.bin
# copying amidar.bin from ROMS/Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/amidar.bin
# copying name_this_game.bin from ROMS/Name This Game (Guardians of Treasure) (1983) (U.S. Games Corporation - JWDA, Roger Booth, Sylvia Day, Ron Dubren, Todd Marshall, Robin McDaniel, Wes Trager, Henry Will IV) (VC1007) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/name_this_game.bin
# copying pitfall.bin from ROMS/Pitfall! - Pitfall Harry's Jungle Adventure (Jungle Runner) (1982) (Activision, David Crane) (AX-018, AX-018-04) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/pitfall.bin
# copying solaris.bin from ROMS/Solaris (The Last Starfighter, Star Raiders II, Universe) (1986) (Atari, Douglas Neubauer, Mimi Nyden) (CX26136) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/solaris.bin
# copying centipede.bin from ROMS/Centipede (1983) (Atari - GCC) (CX2676) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/centipede.bin
# copying carnival.bin from ROMS/Carnival (1982) (Coleco - Woodside Design Associates, Steve 'Jessica Stevens' Kitchen) (2468) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/carnival.bin
# copying time_pilot.bin from ROMS/Time Pilot (1983) (Coleco - Woodside Design Associates, Harley H. Puthuff Jr.) (2663) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/time_pilot.bin
# copying battle_zone.bin from ROMS/Battlezone (1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/battle_zone.bin
# copying bank_heist.bin from ROMS/Bank Heist (Bonnie & Clyde, Cops 'n' Robbers, Hold-Up, Roaring 20's) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11012) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/bank_heist.bin
# copying double_dunk.bin from ROMS/Double Dunk (Super Basketball) (1989) (Atari, Matthew L. Hubbard) (CX26159) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/double_dunk.bin
# copying pong.bin from ROMS/Video Olympics - Pong Sports (Paddle) (1977) (Atari, Joe Decuir - Sears) (CX2621 - 99806, 6-99806, 49-75104) ~.bin to /opt/conda/lib/python3.9/site-packages/atari_py/atari_roms/pong.bin

# %%
#!pip install PyOpenGL_accelerate

# %%
import gym
import random
import OpenGL

# %%
env = gym.make('SpaceInvaders-v0')
#height, width, channels = env.observation_space.shape
#actions = env.action_space.n
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipykernel_40/3062870783.py in <module>
# ----> 1 env = gym.make('SpaceInvaders-v0')
#       2 #height, width, channels = env.observation_space.shape
#       3 #actions = env.action_space.n
#
# /opt/conda/lib/python3.9/site-packages/gym/envs/registration.py in make(id, **kwargs)
#     198
#     199 def make(id, **kwargs):
# --> 200     return registry.make(id, **kwargs)
#     201
#     202
#
# /opt/conda/lib/python3.9/site-packages/gym/envs/registration.py in make(self, path, **kwargs)
#     103             logger.info("Making new env: %s", path)
#     104         spec = self.spec(path)
# --> 105         env = spec.make(**kwargs)
#     106         if env.spec.max_episode_steps is not None:
#     107             from gym.wrappers.time_limit import TimeLimit
#
# /opt/conda/lib/python3.9/site-packages/gym/envs/registration.py in make(self, **kwargs)
#      73         else:
#      74             cls = load(self.entry_point)
# ---> 75             env = cls(**_kwargs)
#      76
#      77         # Make the environment aware of which spec it came from.
#
# /opt/conda/lib/python3.9/site-packages/ale_py/gym/environment.py in __init__(self, game, mode, difficulty, obs_type, frameskip, repeat_action_probability, full_action_space, render_mode)
#     121
#     122         # Seed + Load
# --> 123         self.seed()
#     124
#     125         self._action_set = (
#
# /opt/conda/lib/python3.9/site-packages/ale_py/gym/environment.py in seed(self, seed)
#     169
#     170         if not hasattr(roms, self._game):
# --> 171             raise error.Error(
#     172                 f'Unable to find game "{self._game}", did you import {self._game} with ale-import-roms?'
#     173             )
#
# Error: Unable to find game "SpaceInvaders", did you import SpaceInvaders with ale-import-roms?

# %%
env.unwrapped.get_action_meanings()
# Out:
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']

# %%
occurences = 1

#for _ in occurences:
state = env.reset()
done = False
score = 0

while not done:
    env.render()
    action = random.choice([0,1,2,3,4,5])
    n_state, reward, done, info = env.step(action) 
    score += reward

print('Occurence :{} Score:{}'.format(0, score))
env.close()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/gym/envs/classic_control/rendering.py in <module>
#      24 try:
# ---> 25     from pyglet.gl import *
#      26 except ImportError as e:
#
# /opt/conda/lib/python3.9/site-packages/pyglet/gl/__init__.py in <module>
#      94
# ---> 95 from pyglet.gl.gl import *
#      96 from pyglet.gl.glu import *
#
# /opt/conda/lib/python3.9/site-packages/pyglet/gl/gl.py in <module>
#      44 from ctypes import *
# ---> 45 from pyglet.gl.lib import link_GL as _link_function
#      46 from pyglet.gl.lib import c_ptrdiff_t
#
# /opt/conda/lib/python3.9/site-packages/pyglet/gl/lib.py in <module>
#     148 else:
# --> 149     from pyglet.gl.lib_glx import link_GL, link_GLU, link_GLX
#
# /opt/conda/lib/python3.9/site-packages/pyglet/gl/lib_glx.py in <module>
#      45 gl_lib = pyglet.lib.load_library('GL')
# ---> 46 glu_lib = pyglet.lib.load_library('GLU')
#      47
#
# /opt/conda/lib/python3.9/site-packages/pyglet/lib.py in load_library(self, *names, **kwargs)
#     163
# --> 164         raise ImportError('Library "%s" not found.' % names[0])
#     165
#
# ImportError: Library "GLU" not found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_76/3741338396.py in <module>
#       7
#       8 while not done:
# ----> 9     env.render()
#      10     action = random.choice([0,1,2,3,4,5])
#      11     n_state, reward, done, info = env.step(action)
#
# /opt/conda/lib/python3.9/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# /opt/conda/lib/python3.9/site-packages/gym/envs/atari/atari_env.py in render(self, mode)
#     150             return img
#     151         elif mode == 'human':
# --> 152             from gym.envs.classic_control import rendering
#     153             if self.viewer is None:
#     154                 self.viewer = rendering.SimpleImageViewer()
#
# /opt/conda/lib/python3.9/site-packages/gym/envs/classic_control/rendering.py in <module>
#      25     from pyglet.gl import *
#      26 except ImportError as e:
# ---> 27     raise ImportError('''
#      28     Error occurred while running `from pyglet.gl import *`
#      29     HINT: make sure you have OpenGL install. On Ubuntu, you can run 'apt-get install python-opengl'.
#
# ImportError:
#     Error occurred while running `from pyglet.gl import *`
#     HINT: make sure you have OpenGL install. On Ubuntu, you can run 'apt-get install python-opengl'.
#     If you're running on a server, you may need a virtual frame buffer; something like this should work:
#     'xvfb-run -s "-screen 0 1400x900x24" python <your_script.py>'
