# %% [markdown]
# # Introduction
#
# The purpose of this notebook: test libraries with dummy examples, step afterward is to automate in CICD.
#
# Import and uses:
#
#     numpy
#     matplotlib
#     scikitlearn
#
# This example of Jupyter Notebook is taken from a larger set of examples.
# See the Jupyter Notebook reference: https://github.com/jupyter/jupyter/wiki/A-gallery-of-interesting-Jupyter-Notebooks

# %%
import numpy as np

# datasource
# generate random data-set
np.random.seed(0)
x = np.random.rand(1000, 1)
y = 4 + x**2 + np.random.rand(1000, 1)

# %%
from sklearn.linear_model import LinearRegression

# Model initialization
regression_model = LinearRegression()

# Train the model - fit the data
regression_model.fit(x, y)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Predict
y_predicted = regression_model.predict(x)

# model evaluation
rmse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)

# %%
import matplotlib.pyplot as plt

# printing values
print('Slope:' ,regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)

# plotting values

# data points
plt.scatter(x, y, s=10)
plt.xlabel('x')
plt.ylabel('y')

# predicted values
plt.plot(x, y_predicted, color='r')
plt.show()
# Out:
# Slope: [[1.01656198]]
# Intercept: [4.33760086]
# Root mean squared error:  0.09505595193797137
# R2 score:  0.47864280773137824
